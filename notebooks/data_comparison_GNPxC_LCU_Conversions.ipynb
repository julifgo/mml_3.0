# %%
import pandas as pd
import numpy as np
#Load common functions
# %run common.ipynb
import ipynb.fs.full.common as common
pd.set_option('display.max_columns', None)

# %% [markdown]
# # data_comparison_GNPxC_LCU_Conversions
# ## NOTA IMPORTANTE:
# - MML habla de GNP (Gross National Product) == PNB (Producto Bruto Nacional)
#
# Sin embargo, no encontramos existencia de datos de GNP año a año desde 1960 hasta al menos 2000, país por país, para todos los países.
# Consultado con Igal, corroboró que no se suele trabajar con GNP.
#
# - El set de datos a comparar entonces es GDP (Gross Domestic Product) == PIB (Producto Interno Bruto)
#
# - La comparación no es directa. Sin embargo, podemos asumir que la diferencia entre GNP y GDP de cada pais es NO significativa.
#
# Más aún, si llegarámos a encontrar algun dataset de GNP de algún país en algun periodo, podriamos efectivamente compararlos. Tal vez, teniendo un candidato de país importante por región alcance (uno de LAM, uno de DEVELOPED, etc)
#
# Otro punto a tener en cuenta es la unidad de medida.
# - MML midio GNP a valor USD de 1960
# - Notas de Igal: https://es.overleaf.com/9742826469tmfsvjwrxktq
#
# Vamos a intentar reproducir el cambio de base como evidencia de la posibilidad, para un pais en particular.

# %%
MML_VARIABLE_ANALYZED = 'GNPXC'
REGION = 'ASIA' 
COUNTRY_COL_NAME = 'country'

# %%
df_lcu_current = pd.read_excel(f"data/{REGION}/GDP Current LCU.xlsx", sheet_name='ny_gdp_pcap_cn')
df_lcu_constant = pd.read_excel(f"data/{REGION}/GDP Constant LCU.xlsx", sheet_name='ny_gdp_pcap_kn')
df_lcu_current.columns = df_lcu_current.columns.astype(str)
df_lcu_constant.columns = df_lcu_constant.columns.astype(str)

# %%
df_lcu_current[0:10]
# Out:
#                 country  1959  1960  1961  1962  1963  1964  1965  1966  1967  \
# 0                 Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1           Afghanistan  2690  2690  2630  3540  3690  4550  6190  7240  5810
# 2                Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3               Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4               Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5  United Arab Emirates   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 6             Argentina     0     0     0     0     0     0     0     0     0
# 7               Armenia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8        American Samoa   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9   Antigua and Barbuda   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1968  1969  1970  1971  1972  1973  1974  1975   1976   1977  1978  \
# ...

# %%
#CHEQUEAR EXISTENCIA DE NANS en LAM
#ES OBVIO QUE EL DATASET ESTA INCOMPLETO, PERO CON SUERTE TENEMOS UNA REGION COMPLETA??

# %%
def fix_countries_for_region(df, region=REGION):
    '''Match country column name in dataset with MML dict of country names for region.
    Unfortunately, it's a manual job. We know which names are missing according to MML, but we don't how the truth dataset named that country (if exists at all).
    
    '''
    if region == 'DEVELOPED':
        fix_countries_for_developed(df)
    if region == 'LAM':
        fix_countries_for_lam(df)
    if region == 'AFRICA':
        fix_countries_for_africa(df)
    if region == 'ASIA':
        fix_countries_for_asia(df)
def fix_countries_for_lam(df):
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Brazil', 'Brasil')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Trinidad and Tobago', 'Trinidad y Tobago')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Dominican Republic', 'Republica Dominicana')
def fix_countries_for_developed(df):
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Ukraine', 'Ucrania')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Bosnia and Herzegovina','Bosnia y Herzegovina')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Kyrgyz Republic','Kirguistan')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Germany','Alemania')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'France','Francia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Macedonia, FYR','Macedonia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Slovenia','Eslovenia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Slovak Republic','Eslovaquia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Switzerland','Suiza')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Denmark','Dinamarca')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'United Kingdom','Reino Unido')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'New Zealand','Nueva Zelanda')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Spain','España')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Poland','Polonia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Ireland','Irlanda')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Romania','Rumania')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Finland','Finlandia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Moldova','Moldavia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Sweden','Suecia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Kazakhstan','Kazajistan')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Russia','Rusia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Latvia','Letonia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Norway','Noruega')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Lebanon','Libano')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Czech Republic','Republica Checa')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Hungary','Hungria')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Azerbaijan','Azerbaiyan')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Japan','Japon')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'United States','EEUU')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Greece','Grecia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Italy','Italia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Belgium','Belgica')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Belarus','Bielorrusia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Tajikistan','Tayikistan')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Croatia','Croacia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Lithuania','Lituania')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'Netherlands','Paises Bajos')
    common.replace_value_in_column(df,COUNTRY_COL_NAME,'North Macedonia','Macedonia')
def fix_countries_for_africa(df):
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Morocco', 'Marruecos')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Sierra Leone', 'Sierra Leona')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Algeria', 'Argelia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Kenya', 'Kenia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Egypt', 'Egipto')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Tunisia', 'Tunez')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Libya', 'Libia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Zimbabwe', 'Rhodesia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Congo, Dem. Rep.', 'Zaire')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Congo, Rep.', 'Congo')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Cameroon', 'Camerun')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Ethiopia', 'Etiopia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, "Cote d'Ivoire", 'Costa de Marfil')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Central African Republic', 'Centroafrica')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'United Republic of Tanzania', 'Tanzania')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'South Africa', 'Sudafrica')
def fix_countries_for_asia(df):
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Thailand', 'Tailandia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Papua New Guinea', 'Nueva Guinea')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Iraq', 'Irak')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Philippines', 'Filipinas')
    # common.replace_value_in_column(df,COUNTRY_COL_NAME, 'China, Taiwan Province of China', 'Taiwan')
    # common.replace_value_in_column(df,COUNTRY_COL_NAME, "Dem. People's Republic of Korea", 'Corea del Norte')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'South Korea', 'Corea del Sur')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Syria', 'Siria')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Iran (Islamic Republic of)', 'Iran')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Malaysia', 'Malasia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Myanmar', 'Birmania')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Jordan', 'Jordania')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Singapore', 'Singapur')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Hong Kong, China', 'Hong Kong')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Viet Nam', 'Vietnam')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Cambodia', 'Camboya')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Turkey', 'Turquia')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Afghanistan', 'Afganistan')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, "Lao", 'Laos')
    common.replace_value_in_column(df,COUNTRY_COL_NAME, 'Saudi Arabia', 'Arabia Saudita')

# %%
print(f"Missing countries for region {REGION}")
missing_countries = common.get_missing_countries_for_region(df_lcu_current, COUNTRY_COL_NAME, REGION)
print(missing_countries)
fix_countries_for_region(df_lcu_current)
missing_countries = common.get_missing_countries_for_region(df_lcu_current, COUNTRY_COL_NAME, REGION)
print("Missing countries for region after fix")
print(missing_countries)
print(f"Missing countries for region {REGION}")
missing_countries = common.get_missing_countries_for_region(df_lcu_constant, COUNTRY_COL_NAME, REGION)
print(missing_countries)
fix_countries_for_region(df_lcu_constant)
missing_countries = common.get_missing_countries_for_region(df_lcu_constant, COUNTRY_COL_NAME, REGION)
print("Missing countries for region after fix")
print(missing_countries)
# Out:
# Missing countries for region ASIA
# {'Tailandia', 'Afganistan', 'Singapur', 'Camboya', 'Arabia Saudita', 'Nueva Guinea', 'Corea del Sur', 'Irak', 'Birmania', 'Hong Kong', 'Taiwan', 'Malasia', 'Jordania', 'Siria', 'Turquia', 'Corea del Norte', 'Laos', 'Filipinas'}
# Missing countries for region after fix
# {'Taiwan', 'Corea del Norte'}
# Missing countries for region ASIA
# {'Tailandia', 'Afganistan', 'Singapur', 'Camboya', 'Arabia Saudita', 'Nueva Guinea', 'Corea del Sur', 'Irak', 'Birmania', 'Hong Kong', 'Taiwan', 'Malasia', 'Jordania', 'Siria', 'Turquia', 'Corea del Norte', 'Laos', 'Filipinas'}
# Missing countries for region after fix
# {'Taiwan', 'Corea del Norte'}

# %%
#Filter countries for region
df_lcu_current = common.get_countries_for_region(df_lcu_current, COUNTRY_COL_NAME, REGION)
df_lcu_constant = common.get_countries_for_region(df_lcu_constant, COUNTRY_COL_NAME, REGION)
years_filtered = np.arange(1960,2001,1)
columns_filter = np.append([COUNTRY_COL_NAME],years_filtered)

#Filter years of interest
df_lcu_current = df_lcu_current[columns_filter]
df_lcu_constant = df_lcu_constant[columns_filter]

# %%
assert 0 == df_lcu_current.isna().sum().sum(), "MISSING VALUES FOR LCU CURRENT GDP" #If 0, then we don't have missing values.
assert not (df_lcu_current == 0).any().any(), "CELLS WITH 0 FOR LCU CURRENT GDP"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 assert 0 == df_lcu_current.isna().sum().sum(), "MISSING VALUES FOR LCU CURRENT GDP" #If 0, then we don't have missing values.
#       2 assert not (df_lcu_current == 0).any().any(), "CELLS WITH 0 FOR LCU CURRENT GDP"
#
# AssertionError: MISSING VALUES FOR LCU CURRENT GDP

# %%
assert 0 == df_lcu_constant.isna().sum().sum(), "MISSING VALUES FOR LCU CONSTANT GDP" #If 0, then we don't have missing values.
assert not (df_lcu_constant == 0).any().any(), "CELLS WITH 0 FOR LCU CONSTANT GDP"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 assert 0 == df_lcu_constant.isna().sum().sum(), "MISSING VALUES FOR LCU CONSTANT GDP" #If 0, then we don't have missing values.
#       2 assert not (df_lcu_constant == 0).any().any(), "CELLS WITH 0 FOR LCU CONSTANT GDP"
#
# AssertionError: MISSING VALUES FOR LCU CONSTANT GDP

# %% [raw]
# df_lcu_current = df_lcu_current[df_lcu_current[COUNTRY_COL_NAME] == 'Argentina']
# df_lcu_constant = df_lcu_constant[df_lcu_constant[COUNTRY_COL_NAME] == 'Argentina']

# %%
display(df_lcu_current)
display(df_lcu_constant)
# Out:
#             country     1960     1961     1962     1963     1964   1965  \
# 1        Afganistan     2690     2630     3540     3690     4550   6190
# 17       Bangladesh      468      481      489      481      512    541
# 36            China      187      175      183      210      242    257
# 81        Hong Kong     2350     2630     3050     3390     3880   3930
# 86        Indonesia     5220    14.4k    33.8k    73.1k     236k   3070
# 87            India      406      428      482      550      568    630
# 89             Iran    14.9k    15.4k    15.8k    16.8k    18.8k  20.1k
# 90             Irak     87.5       91     89.6      103      NaN    NaN
# 95         Jordania      NaN      NaN      NaN      NaN      183    185
# 100         Camboya     3830     3830     4120     4330     4700   4860
# 103   Corea del Sur    11.7k    13.8k      19k    26.4k      29k  36.2k
# 106            Laos      NaN      NaN      NaN      NaN      NaN    NaN
# ...

# %% [raw]
# df_lcu = pd.concat([df_lcu_current, df_lcu_constant], axis=0)
# df_lcu = df_lcu.rename({COUNTRY_COL_NAME: 'Type'}, axis=1).reset_index(drop=True)
# df_lcu.at[0,'Type'] = 'current'
# df_lcu.at[1,'Type'] = 'constant'
# display(df_lcu)
