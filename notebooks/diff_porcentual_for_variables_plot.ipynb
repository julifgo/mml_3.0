# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import ipynb.fs.full.common as common

# %%
REGION = "LAM"
VARIABLES = ['EXLIFE', 'POP', 'GNPXC']
df = pd.read_excel(f"data/output/diff_porcentual_{REGION}.xlsx")

# %%
df[0:5]
# Out:
#    Year    EXLIFE       POP      GNPXC
# 0  1970 -1.510596 -3.815155 -21.728502
# 1  1972 -2.059146 -3.617706 -25.080610
# 2  1974 -3.045146 -3.295589 -27.100101
# 3  1976 -3.332473 -2.871311 -27.069090
# 4  1978 -4.016276 -2.352886 -28.882522

# %%
#PLOT HEATMAP!!
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
def plot_heatmap(values,x_labels, y_labels, title, include_values=False, value_fmt='.3f'):
    plt.figure(figsize=(30,3))
    cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['red','orange', 'white','orange', 'red'])
    ax = sns.heatmap(values.T, cmap='RdYlBu', xticklabels=y_labels,yticklabels=x_labels, linewidth = 0.05, annot=include_values, fmt=value_fmt, vmin=-25, vmax=25)
    # ax.invert_xaxis()
    plt.title(title)
    plt.show()

# %%
plot_heatmap(df[VARIABLES],VARIABLES, df['Year'], f"Heatmap with porcentual differences between measured data and MML standard simulation outputs for {common.regions[REGION]['name']}", include_values=True)
